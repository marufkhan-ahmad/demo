# %%
import pickle
database = {'color' : ['white', 'red'], 'value':[5,7]}
pickled_data = pickle.dumps(database)

# %%
print(pickled_data)
# Out:
# b'\x80\x04\x95/\x00\x00\x00\x00\x00\x00\x00}\x94(\x8c\x05color\x94]\x94(\x8c\x05white\x94\x8c\x03red\x94e\x8c\x05value\x94]\x94(K\x05K\x07eu.'

# %%
nframe = pickle.loads(pickled_data)
nframe
# Out:
# {'color': ['white', 'red'], 'value': [5, 7]}

# %%
import pandas as pd
location_data = pd.read_csv(r"C:\Users\mk744\Downloads\365 data science data sets\Python BootCamp\companydataset.csv",
                            usecols= ['StringID', 'Location', 'Region'],
                            index_col= 'StringID')
location_data.head()
# Out:
#              Location    Region
# StringID
# LoanID_1   Location 3  Region 2
# LoanID_2   Location 6  Region 6
# LoanID_3   Location 8  Region 3
# LoanID_4  Location 26  Region 2
# LoanID_5  Location 34  Region 3

# %%
filename = r"C:\Users\mk744\Downloads\365 data science data sets\Python BootCamp\companydataset.csv"
my_csv_data = pd.read_csv(filename)
my_csv_data.head()
# Out:
#    LoanID  StringID    Product CustomerGender     Location    Region  \
# 0       1  LoanID_1  Product B         Female   Location 3  Region 2
# 1       2  LoanID_2  Product D         Female   Location 6  Region 6
# 2       3  LoanID_3  Product B           Male   Location 8  Region 3
# 3       4  LoanID_4  Product A           Male  Location 26  Region 2
# 4       5  LoanID_5  Product B         Female  Location 34  Region 3
#
#    TotalPrice   StartDate  Deposit  DailyRate  TotalDaysYr  AmtPaid36  \
# 0     17600.0  04/07/2018     2200         45          365       3221
# 1         NaN  02/01/2019     2200         45          365       3161
# 2     16600.0  08/12/2016     1000         45          365       2260
# 3     17600.0         NaN     2200         45          365       3141
# 4     21250.0  28/10/2017     2200         55          365       3570
#
#    AmtPaid60  AmtPaid360 LoanStatus
# 0       4166       14621     Active
# 1       4096       16041     Active
# ...

# %%
# Use delimeters and sep
my_csv_data = pd.read_csv(filename, sep = '\,')
my_csv_data.head()
# Out:
# C:\Users\mk744\AppData\Local\Temp\ipykernel_38068\1456818402.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   my_csv_data = pd.read_csv(filename, sep = '\,')
#    LoanID  StringID    Product CustomerGender     Location    Region  \
# 0       1  LoanID_1  Product B         Female   Location 3  Region 2
# 1       2  LoanID_2  Product D         Female   Location 6  Region 6
# 2       3  LoanID_3  Product B           Male   Location 8  Region 3
# 3       4  LoanID_4  Product A           Male  Location 26  Region 2
# 4       5  LoanID_5  Product B         Female  Location 34  Region 3
#
#    TotalPrice   StartDate  Deposit  DailyRate  TotalDaysYr  AmtPaid36  \
# 0     17600.0  04/07/2018     2200         45          365       3221
# ...

# %%
# to remove warning use engin = 'python'
my_csv_data = pd.read_csv(filename, sep ='\,', engine = 'python')
my_csv_data.head()
# Out:
#    LoanID  StringID    Product CustomerGender     Location    Region  \
# 0       1  LoanID_1  Product B         Female   Location 3  Region 2
# 1       2  LoanID_2  Product D         Female   Location 6  Region 6
# 2       3  LoanID_3  Product B           Male   Location 8  Region 3
# 3       4  LoanID_4  Product A           Male  Location 26  Region 2
# 4       5  LoanID_5  Product B         Female  Location 34  Region 3
#
#    TotalPrice   StartDate  Deposit  DailyRate  TotalDaysYr  AmtPaid36  \
# 0     17600.0  04/07/2018     2200         45          365       3221
# 1         NaN  02/01/2019     2200         45          365       3161
# 2     16600.0  08/12/2016     1000         45          365       2260
# 3     17600.0         NaN     2200         45          365       3141
# 4     21250.0  28/10/2017     2200         55          365       3570
#
#    AmtPaid60  AmtPaid360 LoanStatus
# 0       4166       14621     Active
# 1       4096       16041     Active
# ...

# %%
my_csv_data = pd.read_csv(filename, delimiter = '\,', engine = 'python')
my_csv_data.head()
# Out:
#    LoanID  StringID    Product CustomerGender     Location    Region  \
# 0       1  LoanID_1  Product B         Female   Location 3  Region 2
# 1       2  LoanID_2  Product D         Female   Location 6  Region 6
# 2       3  LoanID_3  Product B           Male   Location 8  Region 3
# 3       4  LoanID_4  Product A           Male  Location 26  Region 2
# 4       5  LoanID_5  Product B         Female  Location 34  Region 3
#
#    TotalPrice   StartDate  Deposit  DailyRate  TotalDaysYr  AmtPaid36  \
# 0     17600.0  04/07/2018     2200         45          365       3221
# 1         NaN  02/01/2019     2200         45          365       3161
# 2     16600.0  08/12/2016     1000         45          365       2260
# 3     17600.0         NaN     2200         45          365       3141
# 4     21250.0  28/10/2017     2200         55          365       3570
#
#    AmtPaid60  AmtPaid360 LoanStatus
# 0       4166       14621     Active
# 1       4096       16041     Active
# ...

# %%
# Importing Data with the Squeeze Method 
my_df = pd.read_csv(r"C:\Users\mk744\Downloads\365 data science data sets\Python BootCamp\companydataset.csv")
my_df.head()
# Out:
#    LoanID  StringID    Product CustomerGender     Location    Region  \
# 0       1  LoanID_1  Product B         Female   Location 3  Region 2
# 1       2  LoanID_2  Product D         Female   Location 6  Region 6
# 2       3  LoanID_3  Product B           Male   Location 8  Region 3
# 3       4  LoanID_4  Product A           Male  Location 26  Region 2
# 4       5  LoanID_5  Product B         Female  Location 34  Region 3
#
#    TotalPrice   StartDate  Deposit  DailyRate  TotalDaysYr  AmtPaid36  \
# 0     17600.0  04/07/2018     2200         45          365       3221
# 1         NaN  02/01/2019     2200         45          365       3161
# 2     16600.0  08/12/2016     1000         45          365       2260
# 3     17600.0         NaN     2200         45          365       3141
# 4     21250.0  28/10/2017     2200         55          365       3570
#
#    AmtPaid60  AmtPaid360 LoanStatus
# 0       4166       14621     Active
# 1       4096       16041     Active
# ...

# %%
type(my_df)
# Out:
# pandas.core.frame.DataFrame

# %%
df_usecols = pd.read_csv(r"C:\Users\mk744\Downloads\365 data science data sets\Python BootCamp\companydataset.csv",
                         usecols=['Product'])
df_usecols
# Out:
#         Product
# 0     Product B
# 1     Product D
# 2     Product B
# 3     Product A
# 4     Product B
# ...         ...
# 1038  Product B
# 1039  Product A
# 1040  Product A
# 1041  Product B
# 1042  Product A
#
# [1043 rows x 1 columns]

# %%
# to check null values
df_usecols.isnull().sum()
# Out:
# Product    0
# dtype: int64

# %%
# to check data types
df_usecols.dtypes
# Out:
# Product    object
# dtype: object

# %%
type(df_usecols)
# Out:
# pandas.core.frame.DataFrame

# %%
df_single_col = pd.read_csv(r"C:\Users\mk744\Downloads\365 data science data sets\Python BootCamp\companydataset.csv",
                            usecols=['CustomerGender'])
df_single_col.head()
# Out:
#   CustomerGender
# 0         Female
# 1         Female
# 2           Male
# 3           Male
# 4         Female

# %%
df_single_col
# Out:
#      CustomerGender
# 0            Female
# 1            Female
# 2              Male
# 3              Male
# 4            Female
# ...             ...
# 1038           Male
# 1039           Male
# 1040   NotSpecified
# 1041         Female
# 1042   NotSpecified
#
# [1043 rows x 1 columns]

# %%
df_double_col =pd.read_csv(r"C:\Users\mk744\Downloads\365 data science data sets\Python BootCamp\companydataset.csv",
                           usecols= ['Deposit'])

# %%
df_double_col
# Out:
#       Deposit
# 0        2200
# 1        2200
# 2        1000
# 3        2200
# 4        2200
# ...       ...
# 1038     2200
# 1039     2200
# 1040     2200
# 1041     1000
# 1042     2200
#
# [1043 rows x 1 columns]

# %%
df_single_col.isnull().sum()
# Out:
# CustomerGender    0
# dtype: int64

# %%
df_double_col.isnull().sum()
# Out:
# Deposit    0
# dtype: int64

# %%
# Use squeeze method to read the value in series
use_triple_col = pd.read_csv(r"C:\Users\mk744\Downloads\365 data science data sets\Python BootCamp\companydataset.csv",
                             usecols=['Product'])
df_squeeze = use_triple_col.squeeze('columns')
df_squeeze.head()
# Out:
# 0    Product B
# 1    Product D
# 2    Product B
# 3    Product A
# 4    Product B
# Name: Product, dtype: object

# %%
type(df_squeeze)
# Out:
# pandas.core.series.Series

# %%
# use our data columns in a vertical column
df_squeeze = use_triple_col.squeeze(1)
df_squeeze
# Out:
# 0       Product B
# 1       Product D
# 2       Product B
# 3       Product A
# 4       Product B
#           ...
# 1038    Product B
# 1039    Product A
# 1040    Product A
# 1041    Product B
# 1042    Product A
# Name: Product, Length: 1043, dtype: object

# %%
sample = pd.read_csv(r"C:\Users\mk744\Downloads\365 data science data sets\Python BootCamp\companydataset.csv",
                     usecols= ['TotalPrice', 'Location', 	'Deposit'])
sample
# Out:
#          Location  TotalPrice  Deposit
# 0      Location 3     17600.0     2200
# 1      Location 6         NaN     2200
# 2      Location 8     16600.0     1000
# 3     Location 26     17600.0     2200
# 4     Location 34     21250.0     2200
# ...           ...         ...      ...
# 1038  Location 73     17300.0     2200
# 1039  Location 82         NaN     2200
# 1040  Location 11     17300.0     2200
# 1041  Location 26     16300.0     1000
# 1042  Location 94     17300.0     2200
#
# [1043 rows x 3 columns]

# %%
sample.isnull().sum()
# Out:
# Location       0
# TotalPrice    25
# Deposit        0
# dtype: int64

# %%
sample.fillna(0)
# Out:
#          Location  TotalPrice  Deposit
# 0      Location 3     17600.0     2200
# 1      Location 6         0.0     2200
# 2      Location 8     16600.0     1000
# 3     Location 26     17600.0     2200
# 4     Location 34     21250.0     2200
# ...           ...         ...      ...
# 1038  Location 73     17300.0     2200
# 1039  Location 82         0.0     2200
# 1040  Location 11     17300.0     2200
# 1041  Location 26     16300.0     1000
# 1042  Location 94     17300.0     2200
#
# [1043 rows x 3 columns]

# %%
my_df.isnull().sum()
# Out:
# LoanID             0
# StringID           0
# Product            0
# CustomerGender     0
# Location           0
# Region             1
# TotalPrice        25
# StartDate          1
# Deposit            0
# DailyRate          0
# TotalDaysYr        0
# AmtPaid36          0
# AmtPaid60          0
# AmtPaid360         0
# LoanStatus        37
# dtype: int64

# %%
my_df['Region'].fillna('missing', inplace=True)
my_df.isnull().sum()
# Out:
# LoanID             0
# StringID           0
# Product            0
# CustomerGender     0
# Location           0
# Region             0
# TotalPrice        25
# StartDate          1
# Deposit            0
# DailyRate          0
# TotalDaysYr        0
# AmtPaid36          0
# AmtPaid60          0
# AmtPaid360         0
# LoanStatus        37
# dtype: int64

# %%
my_df["TotalPrice"].fillna("missing data", inplace=True)
my_df.isnull().sum()
# Out:
# LoanID             0
# StringID           0
# Product            0
# CustomerGender     0
# Location           0
# Region             0
# TotalPrice         0
# StartDate          1
# Deposit            0
# DailyRate          0
# TotalDaysYr        0
# AmtPaid36          0
# AmtPaid60          0
# AmtPaid360         0
# LoanStatus        37
# dtype: int64

# %%
my_df["LoanStatus"].fillna("missing value",inplace=True)
my_df.isnull().sum()
# Out:
# LoanID            0
# StringID          0
# Product           0
# CustomerGender    0
# Location          0
# Region            0
# TotalPrice        0
# StartDate         1
# Deposit           0
# DailyRate         0
# TotalDaysYr       0
# AmtPaid36         0
# AmtPaid60         0
# AmtPaid360        0
# LoanStatus        0
# dtype: int64

# %%
my_df["StartDate"].fillna("missing value",inplace=True)

# %%
my_df.isnull().sum()
# Out:
# LoanID            0
# StringID          0
# Product           0
# CustomerGender    0
# Location          0
# Region            0
# TotalPrice        0
# StartDate         0
# Deposit           0
# DailyRate         0
# TotalDaysYr       0
# AmtPaid36         0
# AmtPaid60         0
# AmtPaid360        0
# LoanStatus        0
# dtype: int64

# %%
my_df.count()
# Out:
# LoanID            1043
# StringID          1043
# Product           1043
# CustomerGender    1043
# Location          1043
# Region            1043
# TotalPrice        1043
# StartDate         1043
# Deposit           1043
# DailyRate         1043
# TotalDaysYr       1043
# AmtPaid36         1043
# AmtPaid60         1043
# AmtPaid360        1043
# LoanStatus        1043
# dtype: int64

# %%
my_df.plot()
# Out:
# <AxesSubplot:>

# %%
my_df.interpolate()
# Out:
#       LoanID     StringID    Product CustomerGender     Location    Region  \
# 0          1     LoanID_1  Product B         Female   Location 3  Region 2
# 1          2     LoanID_2  Product D         Female   Location 6  Region 6
# 2          3     LoanID_3  Product B           Male   Location 8  Region 3
# 3          4     LoanID_4  Product A           Male  Location 26  Region 2
# 4          5     LoanID_5  Product B         Female  Location 34  Region 3
# ...      ...          ...        ...            ...          ...       ...
# 1038    1039  LoanID_1039  Product B           Male  Location 73  Region 6
# 1039    1040  LoanID_1040  Product A           Male  Location 82  Region 1
# 1040    1041  LoanID_1041  Product A   NotSpecified  Location 11  Region 4
# 1041    1042  LoanID_1042  Product B         Female  Location 26  Region 6
# 1042    1043  LoanID_1043  Product A   NotSpecified  Location 94  Region 6
#
# ...

# %%
my_df.interpolate().count()
# Out:
# LoanID            1043
# StringID          1043
# Product           1043
# CustomerGender    1043
# Location          1043
# Region            1043
# TotalPrice        1043
# StartDate         1043
# Deposit           1043
# DailyRate         1043
# TotalDaysYr       1043
# AmtPaid36         1043
# AmtPaid60         1043
# AmtPaid360        1043
# LoanStatus        1043
# dtype: int64

# %%
my_df.interpolate().plot()
# Out:
# <AxesSubplot:>

# %%
# A Note on Importing Files in Jupiter
my_data = pd.read_csv(r"C:\Users\mk744\Downloads\365 data science data sets\Time_series.csv")

# %%
import os, inspect

# %%
if '__file__' not in locals():
     fx = inspect.getframeinfo(inspect.currentframe())[0]
else:
     fx = __file__

# %%
os_dir = os.path.dirname(os.path.abspath(fx))
print(os_dir)
# Out:
# C:\Users\mk744\AppData\Local\Temp\ipykernel_38068

# %%
pd.read_csv(os.path.join(os_dir, r"C:\Users\mk744\Downloads\365 data science data sets\Time_series.csv"))
# Out:
#             Date   GSPC500   FTSE100
# 0       1/3/2000  0.003264  0.000000
# 1       1/4/2000 -0.009549  0.000000
# 2       1/5/2000 -0.038345 -0.038137
# 3       1/6/2000  0.001922 -0.019502
# 4       1/7/2000  0.000956 -0.013571
# ...          ...       ...       ...
# 2865  12/27/2010 -0.002282  0.002135
# 2866  12/28/2010  0.003539  0.000000
# 2867  12/29/2010 -0.000254  0.000000
# 2868  12/30/2010  0.000524 -0.002080
# 2869  12/31/2010 -0.002128 -0.004236
#
# [2870 rows x 3 columns]

# %%
fine = r"C:\Users\mk744\Downloads\365 data science data sets\Time_series.csv"
my_file = pd.read_csv(fine)
my_file.head()
# Out:
#        Date   GSPC500   FTSE100
# 0  1/3/2000  0.003264  0.000000
# 1  1/4/2000 -0.009549  0.000000
# 2  1/5/2000 -0.038345 -0.038137
# 3  1/6/2000  0.001922 -0.019502
# 4  1/7/2000  0.000956 -0.013571

# %%
my_file.to_csv('my-csv-file.csv')

# %%
my_file.to_json('my-json-file.json')

# %%
print(my_file.to_html('my-html-file.html'))
# Out:
# None
