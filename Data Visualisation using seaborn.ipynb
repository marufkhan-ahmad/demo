# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
sns.set(color_codes=True)
# %matplotlib inline

# %%
dataset = pd.read_csv(r"C:\Users\mk744\Downloads\Automobile+29.csv")

# %%
dataset
# Out:
#      symboling  normalized_losses         make fuel_type aspiration  \
# 0            3                168  alfa-romero       gas        std
# 1            3                168  alfa-romero       gas        std
# 2            1                168  alfa-romero       gas        std
# 3            2                164         audi       gas        std
# 4            2                164         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 196         -1                 95        volvo       gas        std
# 197         -1                 95        volvo       gas      turbo
# 198         -1                 95        volvo       gas        std
# 199         -1                 95        volvo    diesel      turbo
# 200         -1                 95        volvo       gas      turbo
#
#     number_of_doors   body_style drive_wheels engine_location  wheel_base  \
# 0               two  convertible          rwd           front        88.6
# ...

# %%
dataset.head()
# Out:
#    symboling  normalized_losses         make fuel_type aspiration  \
# 0          3                168  alfa-romero       gas        std
# 1          3                168  alfa-romero       gas        std
# 2          1                168  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   number_of_doors   body_style drive_wheels engine_location  wheel_base  ...  \
# 0             two  convertible          rwd           front        88.6  ...
# 1             two  convertible          rwd           front        88.6  ...
# 2             two    hatchback          rwd           front        94.5  ...
# 3            four        sedan          fwd           front        99.8  ...
# 4            four        sedan          4wd           front        99.4  ...
#
#    engine_size  fuel_system  bore  stroke compression_ratio horsepower  \
# ...

# %%
sns.distplot(dataset['normalized_losses'])
plt.show()

# %%
sns.distplot(dataset['city_mpg'],kde=False, rug=True)
plt.show()

# %%
sns.jointplot(dataset['engine_size'],dataset['horsepower'])
plt.show()

# %%
sns.jointplot(dataset['engine_size'],dataset['horsepower'], kind='reg')
plt.show()

# %%
sns.jointplot(dataset['engine_size'],dataset['horsepower'],kind='kde')
plt.show()

# %%
sns.pairplot(dataset[['normalized_losses','engine_size', 'horsepower']])

# %%
sns.stripplot(dataset['fuel_type'], dataset['horsepower'], jitter=True)
# Out:
# <AxesSubplot:xlabel='fuel_type', ylabel='horsepower'>

# %%
sns.swarmplot(dataset['fuel_type'], dataset['horsepower'])
# Out:
# <AxesSubplot:xlabel='fuel_type', ylabel='horsepower'>

# %%
sns.boxplot(dataset['fuel_type'], dataset['horsepower'],hue=dataset['fuel_type'])
# Out:
# <AxesSubplot:xlabel='fuel_type', ylabel='horsepower'>

# %%
sns.barplot(dataset['fuel_type'], dataset['horsepower'],hue=dataset['fuel_type'])
# Out:
# <AxesSubplot:xlabel='fuel_type', ylabel='horsepower'>

# %%
sns.countplot(dataset['body_style'],hue=dataset['engine_location'])
# Out:
# <AxesSubplot:xlabel='body_style', ylabel='count'>

# %%
sns.pointplot(dataset['fuel_system'],dataset['horsepower'],hue=dataset['number_of_doors'])
# Out:
# <AxesSubplot:xlabel='fuel_system', ylabel='horsepower'>

# %%
# Factor plotting for multipanel categorical part
sns.factorplot(x='fuel_type',
                y='horsepower',
                 hue='number_of_doors',
                 col='engine_location',
                  data= dataset,
                  kind='swarm')

# %%
# Factor plotting for multipanel categorical part
sns.factorplot(x='fuel_type',
                y='horsepower',
                 hue='number_of_doors',
                 col='engine_location',
                  data= dataset,
                  kind='violin')

# %%
# Factor plotting for multipanel categorical part
sns.factorplot(x='fuel_type',
                y='horsepower',
                 hue='number_of_doors',
                 col='engine_location',
                  data= dataset,
                  kind='point')

# %%
# Factor plotting for multipanel categorical part
sns.factorplot(x='fuel_type',
                 hue='number_of_doors',
                 col='engine_location',
                  data= dataset,
                  kind='count')

# %%
# Factor plotting for multipanel categorical part
sns.factorplot(x='fuel_type',
                y='horsepower',
                 hue='number_of_doors',
                 col='engine_location',
                  data= dataset,
                  kind='bar')

# %%
# Factor plotting for multipanel categorical part
sns.factorplot(x='fuel_type',
                y='horsepower',
                 hue='number_of_doors',
                 col='engine_location',
                  data= dataset,
                  kind='strip')

# %%
# how to draw linear regression
sns.lmplot(x="horsepower",y="peak_rpm", data=dataset)

# %%
# how to draw linear regression
sns.lmplot(x="horsepower",y="peak_rpm", data=dataset,hue="fuel_type")
